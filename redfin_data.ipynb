# %%
import pandas as pd

df = pd.read_csv("county_market_tracker.tsv000", sep="\t", header=0)
df.columns
# Out:
# Index(['period_begin', 'period_end', 'period_duration', 'region_type',
#        'region_type_id', 'table_id', 'is_seasonally_adjusted', 'region',
#        'city', 'state', 'state_code', 'property_type', 'property_type_id',
#        'median_sale_price', 'median_sale_price_mom', 'median_sale_price_yoy',
#        'median_list_price', 'median_list_price_mom', 'median_list_price_yoy',
#        'median_ppsf', 'median_ppsf_mom', 'median_ppsf_yoy', 'median_list_ppsf',
#        'median_list_ppsf_mom', 'median_list_ppsf_yoy', 'homes_sold',
#        'homes_sold_mom', 'homes_sold_yoy', 'pending_sales',
#        'pending_sales_mom', 'pending_sales_yoy', 'new_listings',
#        'new_listings_mom', 'new_listings_yoy', 'inventory', 'inventory_mom',
#        'inventory_yoy', 'months_of_supply', 'months_of_supply_mom',
#        'months_of_supply_yoy', 'median_dom', 'median_dom_mom',
#        'median_dom_yoy', 'avg_sale_to_list', 'avg_sale_to_list_mom',
#        'avg_sale_to_list_yoy', 'sold_above_list', 'sold_above_list_mom',
#        'sold_above_list_yoy', 'price_drops', 'price_drops_mom',
#        'price_drops_yoy', 'off_market_in_two_weeks',
#        'off_market_in_two_weeks_mom', 'off_market_in_two_weeks_yoy',
#        'parent_metro_region', 'parent_metro_region_metro_code',
#        'last_updated'],
#       dtype='object')

# %%
df.columns[df.isna().any()].tolist()
# Out:
# ['city',
#  'median_sale_price',
#  'median_sale_price_mom',
#  'median_sale_price_yoy',
#  'median_list_price',
#  'median_list_price_mom',
#  'median_list_price_yoy',
#  'median_ppsf',
#  'median_ppsf_mom',
#  'median_ppsf_yoy',
#  'median_list_ppsf',
#  'median_list_ppsf_mom',
#  'median_list_ppsf_yoy',
#  'homes_sold',
#  'homes_sold_mom',
#  'homes_sold_yoy',
#  'pending_sales',
#  'pending_sales_mom',
#  'pending_sales_yoy',
#  'new_listings',
#  'new_listings_mom',
#  'new_listings_yoy',
#  'inventory',
#  'inventory_mom',
#  'inventory_yoy',
#  'months_of_supply',
#  'months_of_supply_mom',
#  'months_of_supply_yoy',
#  'median_dom',
#  'median_dom_mom',
#  'median_dom_yoy',
#  'avg_sale_to_list',
#  'avg_sale_to_list_mom',
#  'avg_sale_to_list_yoy',
#  'sold_above_list',
#  'sold_above_list_mom',
#  'sold_above_list_yoy',
#  'price_drops',
#  'price_drops_mom',
#  'price_drops_yoy',
#  'off_market_in_two_weeks',
#  'off_market_in_two_weeks_mom',
#  'off_market_in_two_weeks_yoy',
#  'parent_metro_region_metro_code']

# %%
df.head()
# Out:
#   period_begin  period_end  period_duration region_type  region_type_id  \
# 0   2021-12-01  2021-12-31               30      county               5
# 1   2014-09-01  2014-09-30               30      county               5
# 2   2013-08-01  2013-08-31               30      county               5
# 3   2016-03-01  2016-03-31               30      county               5
# 4   2017-04-01  2017-04-30               30      county               5
#
#    table_id is_seasonally_adjusted            region  city     state  ...  \
# 0      2840                      f   Rusk County, TX   NaN     Texas  ...
# 1      2220                      f  Noble County, OH   NaN      Ohio  ...
# 2      3058                      f    Petersburg, VA   NaN  Virginia  ...
# 3      2254                      f  Bryan County, OK   NaN  Oklahoma  ...
# 4       472                      f   Leon County, FL   NaN   Florida  ...
#
#   sold_above_list_yoy price_drops  price_drops_mom  price_drops_yoy  \
# 0                 NaN    0.416667             0.35              NaN
# 1            0.000000         NaN              NaN              NaN
# 2                 NaN         NaN              NaN              NaN
# 3            0.061008         NaN              NaN              NaN
# 4            0.194406         NaN              NaN              NaN
#
#    off_market_in_two_weeks  off_market_in_two_weeks_mom  \
# 0                 0.333333                    -0.166667
# 1                 0.000000                     0.000000
# 2                 0.000000                    -0.333333
# 3                 0.083333                     0.083333
# 4                 0.050000                     0.006522
#
#    off_market_in_two_weeks_yoy        parent_metro_region  \
# 0                          NaN               Longview, TX
# 1                     0.000000  Ohio nonmetropolitan area
# 2                          NaN               Richmond, VA
# 3                     0.083333                 Durant, OK
# 4                     0.019697            Tallahassee, FL
#
#    parent_metro_region_metro_code         last_updated
# 0                         30980.0  2022-02-20 14:26:53
# 1                             NaN  2022-02-20 14:26:53
# 2                         40060.0  2022-02-20 14:26:53
# 3                         20460.0  2022-02-20 14:26:53
# 4                         45220.0  2022-02-20 14:26:53
#
# [5 rows x 58 columns]

# %%
df = df.drop(
    [
        "city", 
        "period_duration", 
        "region_type", 
        "region_type_id", 
        "is_seasonally_adjusted", 
        "last_updated",
        "median_sale_price_mom",
        "median_sale_price_yoy",
        "median_list_price_mom",
        "median_list_price_yoy",
        "median_ppsf_mom",
        "median_ppsf_yoy",
        "median_list_ppsf_mom",
        "median_list_ppsf_yoy",
        "homes_sold_mom",
        "homes_sold_yoy",
        "pending_sales_mom",
        "pending_sales_yoy",
        "new_listings_mom",
        "new_listings_yoy",
        "inventory_mom",
        "inventory_yoy",
        "months_of_supply_mom",
        "months_of_supply_yoy",
        "median_dom_mom",
        "median_dom_yoy",
        "avg_sale_to_list_mom",
        "avg_sale_to_list_yoy",
        "sold_above_list_mom",
        "sold_above_list_yoy",
        "price_drops_mom",
        "price_drops_yoy",
        "off_market_in_two_weeks_mom",
        "off_market_in_two_weeks_yoy",
        "table_id",
        "property_type_id"
    ], 
    axis=1
)
df.head()
# Out:
#   period_begin  period_end            region     state state_code  \
# 0   2021-12-01  2021-12-31   Rusk County, TX     Texas         TX
# 1   2014-09-01  2014-09-30  Noble County, OH      Ohio         OH
# 2   2013-08-01  2013-08-31    Petersburg, VA  Virginia         VA
# 3   2016-03-01  2016-03-31  Bryan County, OK  Oklahoma         OK
# 4   2017-04-01  2017-04-30   Leon County, FL   Florida         FL
#
#                property_type  median_sale_price  median_list_price  \
# 0            All Residential           172100.0           219950.0
# 1  Single Family Residential           166500.0           125000.0
# 2    Multi-Family (2-4 Unit)            20500.0            94500.0
# 3  Single Family Residential            87500.0           124720.0
# 4                  Townhouse           109750.0           190000.0
#
#    median_ppsf  median_list_ppsf  ...  new_listings  inventory  \
# 0   104.649162        118.786218  ...           2.0       12.0
# 1    96.861472         92.416206  ...           6.0       34.0
# 2    10.009766         60.957297  ...           1.0       10.0
# 3    59.065452         83.148559  ...          26.0       92.0
# 4    95.686625        122.055454  ...          64.0      213.0
#
#    months_of_supply  median_dom  avg_sale_to_list  sold_above_list  \
# 0               3.0        25.0          0.915164         0.250000
# 1               5.7       134.0          0.958793         0.000000
# 2               5.0       295.0          0.854167         0.000000
# 3               3.2       107.0          0.954834         0.137931
# 4               4.1        70.0          0.982365         0.230769
#
#    price_drops  off_market_in_two_weeks        parent_metro_region  \
# 0     0.416667                 0.333333               Longview, TX
# 1          NaN                 0.000000  Ohio nonmetropolitan area
# 2          NaN                 0.000000               Richmond, VA
# 3          NaN                 0.083333                 Durant, OK
# 4          NaN                 0.050000            Tallahassee, FL
#
#    parent_metro_region_metro_code
# 0                         30980.0
# 1                             NaN
# 2                         40060.0
# 3                         20460.0
# 4                         45220.0
#
# [5 rows x 22 columns]

# %%
df = df.dropna()
df.head()
# Out:
#    period_begin  period_end                 region       state state_code  \
# 0    2021-12-01  2021-12-31        Rusk County, TX       Texas         TX
# 8    2017-06-01  2017-06-30        Sauk County, WI   Wisconsin         WI
# 9    2021-03-01  2021-03-31  Gloucester County, NJ  New Jersey         NJ
# 12   2017-10-01  2017-10-31    Seminole County, FL     Florida         FL
# 14   2018-05-01  2018-05-31  Meriwether County, GA     Georgia         GA
#
#                 property_type  median_sale_price  median_list_price  \
# 0             All Residential           172100.0           219950.0
# 8   Single Family Residential           179900.0           189900.0
# 9     Multi-Family (2-4 Unit)           172500.0           239950.0
# 12                  Townhouse           194450.0           240000.0
# 14            All Residential            98750.0           155500.0
#
#     median_ppsf  median_list_ppsf  ...  new_listings  inventory  \
# 0    104.649162        118.786218  ...           2.0       12.0
# 8     97.100831        108.000000  ...         109.0      353.0
# 9     91.333359        144.138373  ...          13.0       27.0
# 12   124.790928        138.709677  ...         110.0      140.0
# 14    58.241462         88.958873  ...          23.0       63.0
#
#     months_of_supply  median_dom  avg_sale_to_list  sold_above_list  \
# 0                3.0        25.0          0.915164         0.250000
# 8                4.2        84.0          0.968541         0.202381
# 9                2.3        17.0          0.957683         0.166667
# 12               1.5        18.0          0.972890         0.177083
# 14               2.3        55.0          0.933320         0.178571
#
#     price_drops  off_market_in_two_weeks  parent_metro_region  \
# 0      0.416667                 0.333333         Longview, TX
# 8      0.232295                 0.258621          Baraboo, WI
# 9      0.222222                 0.600000           Camden, NJ
# 12     0.235714                 0.481928          Orlando, FL
# 14     0.253968                 0.352941          Atlanta, GA
#
#     parent_metro_region_metro_code
# 0                          30980.0
# 8                          12660.0
# 9                          15804.0
# 12                         36740.0
# 14                         12060.0
#
# [5 rows x 22 columns]

# %%
df = df.astype(
    {
        "median_sale_price": "int64", 
        "median_list_price": "int64",
        "homes_sold": "int64",
        "pending_sales": "int64",
        "new_listings": "int64",
        "inventory": "int64",
        "median_dom": "int64",
        "parent_metro_region_metro_code": "int64",
        "median_ppsf": "int64",
        "median_list_ppsf": "int64"
    }
)
df.dtypes
# Out:
# period_begin                       object
# period_end                         object
# region                             object
# state                              object
# state_code                         object
# property_type                      object
# median_sale_price                   int64
# median_list_price                   int64
# median_ppsf                         int64
# median_list_ppsf                    int64
# homes_sold                          int64
# pending_sales                       int64
# new_listings                        int64
# inventory                           int64
# months_of_supply                  float64
# median_dom                          int64
# avg_sale_to_list                  float64
# sold_above_list                   float64
# price_drops                       float64
# off_market_in_two_weeks           float64
# parent_metro_region                object
# parent_metro_region_metro_code      int64
# dtype: object

# %%
df = df[df["region"].str.contains("County|Parish", regex=True)]

# %%
df.head()
# Out:
#    period_begin  period_end                 region       state state_code  \
# 0    2021-12-01  2021-12-31        Rusk County, TX       Texas         TX
# 8    2017-06-01  2017-06-30        Sauk County, WI   Wisconsin         WI
# 9    2021-03-01  2021-03-31  Gloucester County, NJ  New Jersey         NJ
# 12   2017-10-01  2017-10-31    Seminole County, FL     Florida         FL
# 14   2018-05-01  2018-05-31  Meriwether County, GA     Georgia         GA
#
#                 property_type  median_sale_price  median_list_price  \
# 0             All Residential             172100             219950
# 8   Single Family Residential             179900             189900
# 9     Multi-Family (2-4 Unit)             172500             239950
# 12                  Townhouse             194450             240000
# 14            All Residential              98750             155500
#
#     median_ppsf  median_list_ppsf  ...  new_listings  inventory  \
# 0           104               118  ...             2         12
# 8            97               108  ...           109        353
# 9            91               144  ...            13         27
# 12          124               138  ...           110        140
# 14           58                88  ...            23         63
#
#     months_of_supply  median_dom  avg_sale_to_list  sold_above_list  \
# 0                3.0          25          0.915164         0.250000
# 8                4.2          84          0.968541         0.202381
# 9                2.3          17          0.957683         0.166667
# 12               1.5          18          0.972890         0.177083
# 14               2.3          55          0.933320         0.178571
#
#     price_drops  off_market_in_two_weeks  parent_metro_region  \
# 0      0.416667                 0.333333         Longview, TX
# 8      0.232295                 0.258621          Baraboo, WI
# 9      0.222222                 0.600000           Camden, NJ
# 12     0.235714                 0.481928          Orlando, FL
# 14     0.253968                 0.352941          Atlanta, GA
#
#     parent_metro_region_metro_code
# 0                            30980
# 8                            12660
# 9                            15804
# 12                           36740
# 14                           12060
#
# [5 rows x 22 columns]

# %%
df["region"] = df["region"].str.replace("City County", "City")
df[df["region"].str.contains("Parish")]
# Out:
#        period_begin  period_end                           region      state  \
# 184      2019-01-01  2019-01-31           Plaquemines Parish, LA  Louisiana
# 244      2018-09-01  2018-09-30            Tangipahoa Parish, LA  Louisiana
# 1227     2020-11-01  2020-11-30           St. Bernard Parish, LA  Louisiana
# 1281     2018-08-01  2018-08-31           St. Tammany Parish, LA  Louisiana
# 1476     2019-12-01  2019-12-31           St. Tammany Parish, LA  Louisiana
# ...             ...         ...                              ...        ...
# 571482   2019-08-01  2019-08-31           St. Charles Parish, LA  Louisiana
# 571730   2017-03-01  2017-03-31  St. John the Baptist Parish, LA  Louisiana
# 571990   2015-08-01  2015-08-31           St. Charles Parish, LA  Louisiana
# 571996   2019-06-01  2019-06-30             Jefferson Parish, LA  Louisiana
# 572147   2021-06-01  2021-06-30           St. Charles Parish, LA  Louisiana
#
#        state_code              property_type  median_sale_price  \
# 184            LA            All Residential             175000
# 244            LA  Single Family Residential             185000
# 1227           LA            All Residential             210000
# 1281           LA  Single Family Residential             233800
# 1476           LA  Single Family Residential             234265
# ...           ...                        ...                ...
# 571482         LA  Single Family Residential             257500
# 571730         LA  Single Family Residential             146000
# 571990         LA            All Residential             175000
# 571996         LA    Multi-Family (2-4 Unit)             230000
# 572147         LA            All Residential             266500
#
#         median_list_price  median_ppsf  median_list_ppsf  ...  new_listings  \
# 184                274900          102               152  ...            23
# 244                160000          102               105  ...           114
# 1227               189950          127               122  ...            50
# 1281               232640          119               123  ...           364
# 1476               229500          122               123  ...           226
# ...                   ...          ...               ...  ...           ...
# 571482             237500          135               119  ...            44
# 571730             139000           90                92  ...            29
# 571990             249000          107               115  ...            29
# 571996             219000          103               124  ...            13
# 572147             295000          142               147  ...            49
#
#         inventory  months_of_supply  median_dom  avg_sale_to_list  \
# 184            79              15.8          74          0.988133
# 244           588               5.3          83          0.985040
# 1227          108               2.4          57          0.981224
# 1281         1631               4.0          84          0.971607
# 1476         1191               4.2          63          0.976154
# ...           ...               ...         ...               ...
# 571482         90               2.3          25          0.986117
# 571730        124               3.2         245          0.983829
# 571990        170               3.5         127          0.966861
# 571996         19               1.1          20          0.939232
# 572147         56               1.0          12          0.992839
#
#         sold_above_list  price_drops  off_market_in_two_weeks  \
# 184            0.000000     0.240506                 0.800000
# 244            0.126126     0.166667                 0.175439
# 1227           0.200000     0.212963                 0.512195
# 1281           0.106173     0.261189                 0.111111
# 1476           0.112676     0.169605                 0.378531
# ...                 ...          ...                      ...
# 571482         0.275000     0.255556                 0.297297
# 571730         0.256410     0.169355                 0.307692
# 571990         0.102041     0.252941                 0.000000
# 571996         0.352941     0.263158                 0.777778
# 572147         0.303571     0.392857                 0.700000
#
#         parent_metro_region  parent_metro_region_metro_code
# 184         New Orleans, LA                           35380
# 244             Hammond, LA                           25220
# 1227        New Orleans, LA                           35380
# 1281        New Orleans, LA                           35380
# 1476        New Orleans, LA                           35380
# ...                     ...                             ...
# 571482      New Orleans, LA                           35380
# 571730      New Orleans, LA                           35380
# 571990      New Orleans, LA                           35380
# 571996      New Orleans, LA                           35380
# 572147      New Orleans, LA                           35380
#
# [2418 rows x 22 columns]

# %%
df.count()
# Out:
# period_begin                      246307
# period_end                        246307
# region                            246307
# state                             246307
# state_code                        246307
# property_type                     246307
# median_sale_price                 246307
# median_list_price                 246307
# median_ppsf                       246307
# median_list_ppsf                  246307
# homes_sold                        246307
# pending_sales                     246307
# new_listings                      246307
# inventory                         246307
# months_of_supply                  246307
# median_dom                        246307
# avg_sale_to_list                  246307
# sold_above_list                   246307
# price_drops                       246307
# off_market_in_two_weeks           246307
# parent_metro_region               246307
# parent_metro_region_metro_code    246307
# dtype: int64

# %%
df.to_csv("redfin_county_data.csv", index=False, header=True)
