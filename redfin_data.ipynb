# %%
import pandas as pd

df = pd.read_csv("county_market_tracker.tsv000", sep="\t", header=0)
df.columns
# Out:
# Index(['period_begin', 'period_end', 'period_duration', 'region_type',
#        'region_type_id', 'table_id', 'is_seasonally_adjusted', 'region',
#        'city', 'state', 'state_code', 'property_type', 'property_type_id',
#        'median_sale_price', 'median_sale_price_mom', 'median_sale_price_yoy',
#        'median_list_price', 'median_list_price_mom', 'median_list_price_yoy',
#        'median_ppsf', 'median_ppsf_mom', 'median_ppsf_yoy', 'median_list_ppsf',
#        'median_list_ppsf_mom', 'median_list_ppsf_yoy', 'homes_sold',
#        'homes_sold_mom', 'homes_sold_yoy', 'pending_sales',
#        'pending_sales_mom', 'pending_sales_yoy', 'new_listings',
#        'new_listings_mom', 'new_listings_yoy', 'inventory', 'inventory_mom',
#        'inventory_yoy', 'months_of_supply', 'months_of_supply_mom',
#        'months_of_supply_yoy', 'median_dom', 'median_dom_mom',
#        'median_dom_yoy', 'avg_sale_to_list', 'avg_sale_to_list_mom',
#        'avg_sale_to_list_yoy', 'sold_above_list', 'sold_above_list_mom',
#        'sold_above_list_yoy', 'price_drops', 'price_drops_mom',
#        'price_drops_yoy', 'off_market_in_two_weeks',
#        'off_market_in_two_weeks_mom', 'off_market_in_two_weeks_yoy',
#        'parent_metro_region', 'parent_metro_region_metro_code',
#        'last_updated'],
#       dtype='object')

# %%
df.columns[df.isna().any()].tolist()
# Out:
# ['city',
#  'median_sale_price',
#  'median_sale_price_mom',
#  'median_sale_price_yoy',
#  'median_list_price',
#  'median_list_price_mom',
#  'median_list_price_yoy',
#  'median_ppsf',
#  'median_ppsf_mom',
#  'median_ppsf_yoy',
#  'median_list_ppsf',
#  'median_list_ppsf_mom',
#  'median_list_ppsf_yoy',
#  'homes_sold',
#  'homes_sold_mom',
#  'homes_sold_yoy',
#  'pending_sales',
#  'pending_sales_mom',
#  'pending_sales_yoy',
#  'new_listings',
#  'new_listings_mom',
#  'new_listings_yoy',
#  'inventory',
#  'inventory_mom',
#  'inventory_yoy',
#  'months_of_supply',
#  'months_of_supply_mom',
#  'months_of_supply_yoy',
#  'median_dom',
#  'median_dom_mom',
#  'median_dom_yoy',
#  'avg_sale_to_list',
#  'avg_sale_to_list_mom',
#  'avg_sale_to_list_yoy',
#  'sold_above_list',
#  'sold_above_list_mom',
#  'sold_above_list_yoy',
#  'price_drops',
#  'price_drops_mom',
#  'price_drops_yoy',
#  'off_market_in_two_weeks',
#  'off_market_in_two_weeks_mom',
#  'off_market_in_two_weeks_yoy',
#  'parent_metro_region_metro_code']

# %%
df.head()
# Out:
#   period_begin  period_end  period_duration region_type  region_type_id  \
# 0   2021-12-01  2021-12-31               30      county               5
# 1   2014-09-01  2014-09-30               30      county               5
# 2   2013-08-01  2013-08-31               30      county               5
# 3   2016-03-01  2016-03-31               30      county               5
# 4   2017-04-01  2017-04-30               30      county               5
#
#    table_id is_seasonally_adjusted            region  city     state  ...  \
# 0      2840                      f   Rusk County, TX   NaN     Texas  ...
# 1      2220                      f  Noble County, OH   NaN      Ohio  ...
# 2      3058                      f    Petersburg, VA   NaN  Virginia  ...
# 3      2254                      f  Bryan County, OK   NaN  Oklahoma  ...
# 4       472                      f   Leon County, FL   NaN   Florida  ...
#
#   sold_above_list_yoy price_drops  price_drops_mom  price_drops_yoy  \
# 0                 NaN    0.416667             0.35              NaN
# 1            0.000000         NaN              NaN              NaN
# 2                 NaN         NaN              NaN              NaN
# 3            0.061008         NaN              NaN              NaN
# 4            0.194406         NaN              NaN              NaN
#
#    off_market_in_two_weeks  off_market_in_two_weeks_mom  \
# 0                 0.333333                    -0.166667
# 1                 0.000000                     0.000000
# 2                 0.000000                    -0.333333
# 3                 0.083333                     0.083333
# 4                 0.050000                     0.006522
#
#    off_market_in_two_weeks_yoy        parent_metro_region  \
# 0                          NaN               Longview, TX
# 1                     0.000000  Ohio nonmetropolitan area
# 2                          NaN               Richmond, VA
# 3                     0.083333                 Durant, OK
# 4                     0.019697            Tallahassee, FL
#
#    parent_metro_region_metro_code         last_updated
# 0                         30980.0  2022-02-20 14:26:53
# 1                             NaN  2022-02-20 14:26:53
# 2                         40060.0  2022-02-20 14:26:53
# 3                         20460.0  2022-02-20 14:26:53
# 4                         45220.0  2022-02-20 14:26:53
#
# [5 rows x 58 columns]

# %%
df = df.drop(
    [
        "city", 
        "period_duration", 
        "region_type", 
        "region_type_id", 
        "is_seasonally_adjusted", 
        "last_updated",
        "median_sale_price_mom",
        "median_sale_price_yoy",
        "median_list_price_mom",
        "median_list_price_yoy",
        "median_ppsf_mom",
        "median_ppsf_yoy",
        "median_list_ppsf_mom",
        "median_list_ppsf_yoy",
        "homes_sold_mom",
        "homes_sold_yoy",
        "pending_sales_mom",
        "pending_sales_yoy",
        "new_listings_mom",
        "new_listings_yoy",
        "inventory_mom",
        "inventory_yoy",
        "months_of_supply_mom",
        "months_of_supply_yoy",
        "median_dom_mom",
        "median_dom_yoy",
        "avg_sale_to_list_mom",
        "avg_sale_to_list_yoy",
        "sold_above_list_mom",
        "sold_above_list_yoy",
        "price_drops_mom",
        "price_drops_yoy",
        "off_market_in_two_weeks_mom",
        "off_market_in_two_weeks_yoy",
    ], 
    axis=1
)
df.head()
# Out:
#   period_begin  period_end  table_id            region     state state_code  \
# 0   2021-12-01  2021-12-31      2840   Rusk County, TX     Texas         TX
# 1   2014-09-01  2014-09-30      2220  Noble County, OH      Ohio         OH
# 2   2013-08-01  2013-08-31      3058    Petersburg, VA  Virginia         VA
# 3   2016-03-01  2016-03-31      2254  Bryan County, OK  Oklahoma         OK
# 4   2017-04-01  2017-04-30       472   Leon County, FL   Florida         FL
#
#                property_type  property_type_id  median_sale_price  \
# 0            All Residential                -1           172100.0
# 1  Single Family Residential                 6           166500.0
# 2    Multi-Family (2-4 Unit)                 4            20500.0
# 3  Single Family Residential                 6            87500.0
# 4                  Townhouse                13           109750.0
#
#    median_list_price  ...  new_listings  inventory  months_of_supply  \
# 0           219950.0  ...           2.0       12.0               3.0
# 1           125000.0  ...           6.0       34.0               5.7
# 2            94500.0  ...           1.0       10.0               5.0
# 3           124720.0  ...          26.0       92.0               3.2
# 4           190000.0  ...          64.0      213.0               4.1
#
#    median_dom  avg_sale_to_list  sold_above_list  price_drops  \
# 0        25.0          0.915164         0.250000     0.416667
# 1       134.0          0.958793         0.000000          NaN
# 2       295.0          0.854167         0.000000          NaN
# 3       107.0          0.954834         0.137931          NaN
# 4        70.0          0.982365         0.230769          NaN
#
#    off_market_in_two_weeks        parent_metro_region  \
# 0                 0.333333               Longview, TX
# 1                 0.000000  Ohio nonmetropolitan area
# 2                 0.000000               Richmond, VA
# 3                 0.083333                 Durant, OK
# 4                 0.050000            Tallahassee, FL
#
#    parent_metro_region_metro_code
# 0                         30980.0
# 1                             NaN
# 2                         40060.0
# 3                         20460.0
# 4                         45220.0
#
# [5 rows x 24 columns]

# %%
df = df.dropna()
df.head()
# Out:
#    period_begin  period_end  table_id                 region       state  \
# 0    2021-12-01  2021-12-31      2840        Rusk County, TX       Texas
# 8    2017-06-01  2017-06-30      3219        Sauk County, WI   Wisconsin
# 9    2021-03-01  2021-03-31      1898  Gloucester County, NJ  New Jersey
# 12   2017-10-01  2017-10-31       495    Seminole County, FL     Florida
# 14   2018-05-01  2018-05-31       602  Meriwether County, GA     Georgia
#
#    state_code              property_type  property_type_id  median_sale_price  \
# 0          TX            All Residential                -1           172100.0
# 8          WI  Single Family Residential                 6           179900.0
# 9          NJ    Multi-Family (2-4 Unit)                 4           172500.0
# 12         FL                  Townhouse                13           194450.0
# 14         GA            All Residential                -1            98750.0
#
#     median_list_price  ...  new_listings  inventory  months_of_supply  \
# 0            219950.0  ...           2.0       12.0               3.0
# 8            189900.0  ...         109.0      353.0               4.2
# 9            239950.0  ...          13.0       27.0               2.3
# 12           240000.0  ...         110.0      140.0               1.5
# 14           155500.0  ...          23.0       63.0               2.3
#
#     median_dom  avg_sale_to_list  sold_above_list  price_drops  \
# 0         25.0          0.915164         0.250000     0.416667
# 8         84.0          0.968541         0.202381     0.232295
# 9         17.0          0.957683         0.166667     0.222222
# 12        18.0          0.972890         0.177083     0.235714
# 14        55.0          0.933320         0.178571     0.253968
#
#     off_market_in_two_weeks  parent_metro_region  \
# 0                  0.333333         Longview, TX
# 8                  0.258621          Baraboo, WI
# 9                  0.600000           Camden, NJ
# 12                 0.481928          Orlando, FL
# 14                 0.352941          Atlanta, GA
#
#     parent_metro_region_metro_code
# 0                          30980.0
# 8                          12660.0
# 9                          15804.0
# 12                         36740.0
# 14                         12060.0
#
# [5 rows x 24 columns]

# %%
df.count()
# Out:
# period_begin                      253364
# period_end                        253364
# table_id                          253364
# region                            253364
# state                             253364
# state_code                        253364
# property_type                     253364
# property_type_id                  253364
# median_sale_price                 253364
# median_list_price                 253364
# median_ppsf                       253364
# median_list_ppsf                  253364
# homes_sold                        253364
# pending_sales                     253364
# new_listings                      253364
# inventory                         253364
# months_of_supply                  253364
# median_dom                        253364
# avg_sale_to_list                  253364
# sold_above_list                   253364
# price_drops                       253364
# off_market_in_two_weeks           253364
# parent_metro_region               253364
# parent_metro_region_metro_code    253364
# dtype: int64

# %%
df.to_csv("redfin_county_data.csv", index=False, header=True)
